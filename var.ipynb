# %%
import pandas as pd
import numpy as np
from vasicek_model import Vasicek
from matplotlib import pyplot as plt

# %%
def plot(data):
    if data.ndim == 2:
        plt.plot(np.arange(len(data)), np.mean(data, axis=1), color='orange')
    else:
        plt.plot(np.arange(len(data)), data, color='orange')

# %%
# %load_ext autoreload
# %autoreload 2
model = Vasicek()
# Out:
# VaR  Expected Shortfall  Profit & loss  Variance
# 0  0.027998            0.027998      -0.108478  0.055588
# 1  0.018119            0.018119       0.077225  8.147579

# %%
plot(model.rate_P)

# %%
plot(model.Tprice)
