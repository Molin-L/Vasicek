# %%
from vasicek_model import Vasicek
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
def plot(data):
    if data.ndim == 2:
        plt.plot(np.arange(len(data)), np.mean(data, axis=1), color='orange')
    else:
        plt.plot(np.arange(len(data)), data, color='orange')

# %%
# %load_ext autoreload
# %autoreload 2
model = Vasicek()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [[ 0.02        0.02        0.02       ...  0.02        0.02
#    0.02      ]
#  [ 0.01499916  0.02026803  0.01447716 ...  0.01908647  0.01687032
#    0.01817481]
#  [ 0.01456307  0.02500666  0.00756246 ...  0.01209092  0.01619888
#    0.02319623]
#  ...
#  [ 0.05112935  0.00343916  0.00717679 ...  0.04906137  0.00229636
#    0.07652088]
#  [ 0.05493766 -0.00079345  0.00893105 ...  0.04772983  0.00435267
#    0.08163341]
#  [ 0.05380717 -0.00113495  0.00548973 ...  0.04919158  0.00785076
#    0.08777617]]
#         VaR  Expected Shortfall  Profit & loss   Variance
# 0  0.037056            0.037056      -0.084572   0.058590
# 1  0.015414            0.015414       0.062467  12.931056

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10), sharey=False)
axs[0, 0].plot(np.arange(len(np.mean(model.rate_P, axis=1))),
                    np.mean(model.rate_P, axis=1), color='orange')
axs[0, 0].set_title('Interest Rate under P (Practice)')

axs[0, 1].plot(np.arange(len(model.Tprice)), np.mean(model.Tprice, axis=1), color='orange')
axs[0, 1].set_title('Tprice')
axs[0, 2].plot(np.arange(len(model.Sprice)), np.mean(model.Sprice, axis=1), color='orange')
axs[0, 2].set_title('Sprice')
axs[0, 3].plot(np.arange(len(model.Uprice)), np.mean(model.Uprice, axis=1), color='orange')
axs[0, 3].set_title('Uprice')
axs[1, 0].plot(np.arange(len(np.mean(model.rate_P, axis=1))), np.mean(model.rate_P, axis=1), color='orange')
axs[1, 0].set_title('Rate')
axs[1, 1].plot(np.arange(len(np.mean(model.gamma_S, axis=1))), np.mean(model.gamma_S, axis=1), color='orange')
axs[1, 1].set_title('S gamma')
# Out:
# Text(0.5, 1.0, 'S gamma')

# %%
print(np.mean(model.quant_u_gamma))
# Out:
# -0.7471814836174965

# %%
print(np.mean(model.quant_s_gamma))
# Out:
# 1.6592138492935404

# %%
U_price = model._test_cal_price(model.U)
plot(U_price)

# %%
plot(model.pf_s1)

# %%
model.qz_s1
# Out:
# array([[  0.42771345,   0.42830971,   0.42789765, ...,   0.42863526,
#           0.427979  ,   0.4280259 ],
#        [  0.45539423,   0.45400012,   0.45454489, ...,   0.45250607,
#           0.45473858,   0.4543948 ],
#        [  0.47227992,   0.47017438,   0.47263352, ...,   0.47058105,
#           0.47220248,   0.47163148],
#        ...,
#        [ -0.40697248,  -1.74778315,   2.6974752 , ...,   0.31389512,
#          -1.53066697,   0.2371678 ],
#        [ -0.70750942,  -1.19815816,  19.82661586, ...,   3.12540747,
#          -0.08602824,   0.1772586 ],
#        [-25.94941256,  -1.35735197,   5.03656868, ...,  -4.06927689,
#           1.45274507,   0.34565976]])
